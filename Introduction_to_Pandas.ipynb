# %% [markdown]
# <a href="https://colab.research.google.com/github/mohnfeld/Data-Analytics-Batch-Fall-23/blob/main/Introduction_to_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Pandas

# %% [markdown]
# ## Course Outline
#
# 1. **Introduction to Pandas (18 Sep, Mon)**
# 2. Practice Session (20 Sep, Wed)
# 3. Pandas Transformations I (25 Sep, Mon)
# 4. Pandas Transformations II (27 Sep, Wed)
# 5. Cleaning, Handling Missing Data (2 Oct, Mon)

# %% [markdown]
# ## Introduction to Pandas
# *Content for today's session*
#
# 1. What is Pandas?
# 2. Exploring dataframes
# 3. Accessing dataframes
# 4. Sorting and subsetting (filtering)
# 5. Aggregating the dataframe

# %% [markdown]
# ## What is Pandas?
# * Python package for data analysis.
# * Name is derived from *pan*el + *da*ta = *pandas*.
# * Third most downloaded Python package, behind `numpy` and `scipy`.

# %% [markdown]
# ### What can you use pandas knowledge for?
# * Data Manipulation
# * Data Visualisation

# %% [markdown]
# ### Installing Pandas

# %%
# Installing pandas
# !pip install pandas

# %%
# Importing pandas
## pd is the conventional abbreviation used
import pandas as pd

# %% [markdown]
# ### Creating a dataframe

# %%
# You can create your own dataframe
df = pd.DataFrame({"col1":[1,2,3],
                   "col2":['a','b','c']})

df
# Out:
#    col1 col2
# 0     1    a
# 1     2    b
# 2     3    c

# %%
# Or you can read CSV data into a dataframe
cars = pd.read_csv("https://raw.githubusercontent.com/juliandnl/redi_ss20/master/cars.csv")

cars
# Out:
#             Make                  Model  Year  \
# 0     Volkswagen                  Vento  2012
# 1           Ford                 Ranger  2012
# 2     Volkswagen                    Fox  2011
# 3           Ford                 Ranger  2017
# 4     Volkswagen                    Gol  2013
# ...          ...                    ...   ...
# 9995        Ford              Focus III  2016
# 9996  Volkswagen                   Bora  2012
# 9997        Ford  Fiesta Kinetic Design  2012
# 9998        Ford  Fiesta Kinetic Design  2013
# 9999        Ford              Focus III  2014
#
#                                Variant     Kms   Price  Doors       Kind  \
# 0                     2.5 Luxury 170cv   99950  360000    4.0      Sedán
# 1                   2.3 Cd Xl Plus 4x2  140000  320000    2.0    Pick-Up
# 2                        1.6 Trendline  132000  209980    5.0  Hatchback
# 3     3.2 Cd Xls Tdci 200cv Automática   13000  798000    4.0    Pick-Up
# ...

# %% [markdown]
# ## Exploring Dataframes
#
# There are methods and attributes of the dataframe which helps you understand more about it.

# %% [markdown]
# ### Methods to get and overview of a dataframe
#
# * `.head()`
# * `.tail()`
# * `.describe()`
# * `.info()`

# %%
cars.head()
# Out:
#          Make   Model  Year                           Variant     Kms   Price  \
# 0  Volkswagen   Vento  2012                  2.5 Luxury 170cv   99950  360000
# 1        Ford  Ranger  2012                2.3 Cd Xl Plus 4x2  140000  320000
# 2  Volkswagen     Fox  2011                     1.6 Trendline  132000  209980
# 3        Ford  Ranger  2017  3.2 Cd Xls Tdci 200cv Automática   13000  798000
# 4  Volkswagen     Gol  2013                1.4 Power 83cv 3 p  107000  146000
#
#    Doors       Kind           Location
# 0    4.0      Sedán            Córdoba
# 1    2.0    Pick-Up         Entre Ríos
# 2    5.0  Hatchback  Bs.as. G.b.a. Sur
# 3    4.0    Pick-Up            Neuquén
# 4    3.0  Hatchback            Córdoba

# %%
cars.tail()
# Out:
#             Make                  Model  Year                    Variant  \
# 9995        Ford              Focus III  2016                     2.0 Se
# 9996  Volkswagen                   Bora  2012      1.9 Trendline I 100cv
# 9997        Ford  Fiesta Kinetic Design  2012  1.6 Design 120cv Titanium
# 9998        Ford  Fiesta Kinetic Design  2013  1.6 Design 120cv Titanium
# 9999        Ford              Focus III  2014           2.0 Titanium At6
#
#          Kms   Price  Doors       Kind               Location
# 9995   67000  399000    5.0  Hatchback    Bs.as. G.b.a. Oeste
# 9996  120000  240000    4.0      Sedán  Buenos Aires Interior
# 9997   89000  250000    5.0  Hatchback                Tucumán
# 9998   76000  295000    5.0  Hatchback  Buenos Aires Interior
# 9999   32000  380000    5.0  Hatchback      Bs.as. G.b.a. Sur

# %%
cars.describe()
# Out:
#                Year            Kms         Price         Doors
# count  10000.000000   10000.000000  1.000000e+04  10000.000000
# mean    2013.293800   74483.338400  3.495455e+05      4.295800
# std        1.816043   35150.279998  1.773396e+05      0.889821
# min     2011.000000    5094.000000  6.300000e+03      2.000000
# 25%     2012.000000   49500.000000  2.290000e+05      4.000000
# 50%     2013.000000   73000.000000  3.000000e+05      5.000000
# 75%     2015.000000   97000.000000  4.300000e+05      5.000000
# max     2018.000000  218000.000000  2.800000e+06      5.000000

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Make      10000 non-null  object
#  1   Model     10000 non-null  object
#  2   Year      10000 non-null  int64
#  3   Variant   10000 non-null  object
#  4   Kms       10000 non-null  int64
#  5   Price     10000 non-null  int64
#  6   Doors     10000 non-null  float64
#  7   Kind      10000 non-null  object
#  8   Location  10000 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 703.2+ KB

# %% [markdown]
# ### Attributes of the dataframe
#
# * `.shape`
# * `.dtype`
# * `.index`
# * `.columns`
# * `.values`

# %%
cars.shape
# Out:
# (10000, 9)

# %%
cars.dtypes
# Out:
# Make         object
# Model        object
# Year          int64
# Variant      object
# Kms           int64
# Price         int64
# Doors       float64
# Kind         object
# Location     object
# dtype: object

# %%
cars.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
cars.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Variant', 'Kms', 'Price', 'Doors', 'Kind',
#        'Location'],
#       dtype='object')

# %%
cars.values
# Out:
# array([['Volkswagen', 'Vento', 2012, ..., 4.0, 'Sedán', 'Córdoba'],
#        ['Ford', 'Ranger', 2012, ..., 2.0, 'Pick-Up', 'Entre Ríos'],
#        ['Volkswagen', 'Fox', 2011, ..., 5.0, 'Hatchback',
#         'Bs.as. G.b.a. Sur'],
#        ...,
#        ['Ford', 'Fiesta Kinetic Design', 2012, ..., 5.0, 'Hatchback',
#         'Tucumán'],
#        ['Ford', 'Fiesta Kinetic Design', 2013, ..., 5.0, 'Hatchback',
#         'Buenos Aires Interior'],
#        ['Ford', 'Focus III', 2014, ..., 5.0, 'Hatchback',
#         'Bs.as. G.b.a. Sur']], dtype=object)

# %% [markdown]
# ## Accessing Dataframes
#
# * Condition-based (`.query()`, `.loc[]`)
# * Label-based (`.loc[]`)
# * Position-based (`.iloc[]`)

# %% [markdown]
# ### Condition-based with `.query()`
#
# Use boolean expressions to filter information on the pandas dataframe.
#
# Recall that boolean expressions are, for example `"Make == 'Volkswagen'"` or `"Year > 2014"`.

# %%
cars.query("Make == 'Volkswagen' & Year >= 2014").head(3)
# Out:
#           Make   Model  Year                              Variant     Kms  \
# 5   Volkswagen  Amarok  2014    2.0 Cd Tdi 180cv 4x4 Highline C34  115000
# 10  Volkswagen  Amarok  2014  2.0 Cd Tdi 4x4 Highline Pack At C34   79900
# 19  Volkswagen     Up!  2015                 1.0 Take Up! Aa 75cv   38000
#
#      Price  Doors       Kind               Location
# 5   790000    4.0    Pick-Up  Buenos Aires Interior
# 10  685000    4.0    Pick-Up    Bs.as. G.b.a. Norte
# 19  220000    3.0  Hatchback      Bs.as. G.b.a. Sur

# %% [markdown]
# Note: Be sure to avoid doing this:
#
# ```
# (cars['Kind'] == 'Volkswagen') & (cars['Year'] > 2014)
# ```

# %% [markdown]
# ### Condition-based with `.loc[]`
#
# 1. Create a "mask" of a Boolean,
# 2. Use that to filter the dataframe.

# %%
# First, prepare a "mask" by creating a boolean
volkswagen_cars = cars['Make'] == 'Volkswagen'
volkswagen_cars
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# Name: Make, Length: 10000, dtype: bool

# %%
# Then use it to filter the dataframe:
cars.loc[volkswagen_cars]
# Out:
#             Make      Model  Year                              Variant  \
# 0     Volkswagen      Vento  2012                     2.5 Luxury 170cv
# 2     Volkswagen        Fox  2011                        1.6 Trendline
# 4     Volkswagen        Gol  2013                   1.4 Power 83cv 3 p
# 5     Volkswagen     Amarok  2014    2.0 Cd Tdi 180cv 4x4 Highline C34
# 10    Volkswagen     Amarok  2014  2.0 Cd Tdi 4x4 Highline Pack At C34
# ...          ...        ...   ...                                  ...
# 9985  Volkswagen  Gol Trend  2016                  1.6 Trendline 101cv
# 9986  Volkswagen        Gol  2013                   1.4 Power 83cv 5 p
# 9987  Volkswagen      Suran  2013                1.6 Comfortline 101cv
# 9992  Volkswagen      Suran  2011            1.6 Imotion Trendline 11b
# 9996  Volkswagen       Bora  2012                1.9 Trendline I 100cv
#
#          Kms   Price  Doors         Kind               Location
# ...

# %% [markdown]
# ### Label-based with `.loc[]`
#
# A dataframe has labels for columns and for rows.
# These can be filtered using `.loc[]`.

# %%
cars.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Variant', 'Kms', 'Price', 'Doors', 'Kind',
#        'Location'],
#       dtype='object')

# %%
index_for_cars = cars.index.tolist()
index_for_cars = ['row_'+str(x) for x in index_for_cars]
cars.index = index_for_cars
cars
# Out:
#                 Make                  Model  Year  \
# row_0     Volkswagen                  Vento  2012
# row_1           Ford                 Ranger  2012
# row_2     Volkswagen                    Fox  2011
# row_3           Ford                 Ranger  2017
# row_4     Volkswagen                    Gol  2013
# ...              ...                    ...   ...
# row_9995        Ford              Focus III  2016
# row_9996  Volkswagen                   Bora  2012
# row_9997        Ford  Fiesta Kinetic Design  2012
# row_9998        Ford  Fiesta Kinetic Design  2013
# row_9999        Ford              Focus III  2014
#
#                                    Variant     Kms   Price  Doors       Kind  \
# row_0                     2.5 Luxury 170cv   99950  360000    4.0      Sedán
# row_1                   2.3 Cd Xl Plus 4x2  140000  320000    2.0    Pick-Up
# row_2                        1.6 Trendline  132000  209980    5.0  Hatchback
# ...

# %%
cars.loc[['row_5','row_6'], 'Kind']
# Out:
# row_5      Pick-Up
# row_6    Hatchback
# Name: Kind, dtype: object

# %% [markdown]
# ### Position-based with `.iloc[]`
#
# Indexing here works the same lists. Starts from 0.

# %%
cars.iloc[0]
# Out:
# Make              Volkswagen
# Model                  Vento
# Year                    2012
# Variant     2.5 Luxury 170cv
# Kms                    99950
# Price                 360000
# Doors                    4.0
# Kind                   Sedán
# Location             Córdoba
# Name: row_0, dtype: object

# %%
# To keep the df format
cars.iloc[0:1]
# Out:
#              Make  Model  Year           Variant    Kms   Price  Doors   Kind  \
# row_0  Volkswagen  Vento  2012  2.5 Luxury 170cv  99950  360000    4.0  Sedán
#
#       Location
# row_0  Córdoba

# %%
# To filter columns
cars.iloc[:,1:2]
# Out:
#                           Model
# row_0                     Vento
# row_1                    Ranger
# row_2                       Fox
# row_3                    Ranger
# row_4                       Gol
# ...                         ...
# row_9995              Focus III
# row_9996                   Bora
# row_9997  Fiesta Kinetic Design
# row_9998  Fiesta Kinetic Design
# row_9999              Focus III
#
# [10000 rows x 1 columns]

# %% [markdown]
# ## Aggregating the Dataframe

# %% [markdown]
# ### General functions
#
# Methods to aggregate columns:
#
# ```
# .sum()
# .mean()
# .median()
# .count()
# .max()
# .min()
# .nunique()
# ```

# %% [markdown]
# ### Group by functions

# %% [markdown]
# ![Screenshot from 2021-09-14 21-49-29.png](data:image/png;base64,...)

# %%
cars_agg = cars.groupby('Make')[['Price','Kms']].mean() # aggregate more than 1 column at a time
cars_agg.reset_index(inplace=True)
cars_agg
# Out:
#             Make          Price           Kms
# 0       Chrysler  366845.833333  79593.958333
# 1           Ford  353041.877764  69897.515776
# 2          Honda  381520.603448  81619.659004
# 3  Mercedes Benz  512749.515625  67358.714844
# 4     Volkswagen  335441.534119  77660.223275

# %% [markdown]
# You can make the output more readable with the method `.round()` that takes 1 argument (the number of decimals).

# %%
make_means = cars.groupby(['Make'])[['Price','Kms']].mean().round(1)
make_means
# Out:
#                   Price      Kms
# Make
# Chrysler       366845.8  79594.0
# Ford           353041.9  69897.5
# Honda          381520.6  81619.7
# Mercedes Benz  512749.5  67358.7
# Volkswagen     335441.5  77660.2

# %% [markdown]
# The `agg()` method allows you to apply multiple functions to the selected columns

# %%
cars.groupby('Make')[['Price']].agg(['mean','sum','count']).round(1)
# Out:
#                   Price
#                    mean         sum count
# Make
# Chrysler       366845.8     8804300    24
# Ford           353041.9  1420993558  4025
# Honda          381520.6   199153755   522
# Mercedes Benz  512749.5   131263876   256
# Volkswagen     335441.5  1735239056  5173

# %%
my_functions = ['mean','count']
my_columns = ['Price','Doors']

price_by_kind = cars.groupby('Kind')[my_columns].agg(my_functions)
price_by_kind
# Out:
#                      Price           Doors
#                       mean count      mean count
# Kind
# Cabriolet     79272.636364    11  2.000000    11
# Coupé        543092.155556    90  2.022222    90
# Furgón       702054.698113    53  2.000000    53
# Hatchback    276554.828649  4056  4.564103  4056
# Minivan      650000.000000     1  2.000000     1
# Monovolumen  270500.202837   705  4.991489   705
# Pick-Up      545194.551390  1547  3.313510  1547
# Rural        330247.118644    59  4.610169    59
# SUV          380707.993103  1305  5.000000  1305
# Sedán        338569.647032  2173  4.000000  2173

# %% [markdown]
# **Using groupby with different functions for different columns using a dictionary**
#
# The `.agg()` method also allows you to apply different functions to different columns. It's done by using a dictionary where the columns selected are the keys, and the functions you want to apply to each columns are the values. There is no need to select the columns before applying `.agg()` in this case, as the columns are selected inside the dictionary.

# %%
cars.groupby('Kind').agg({'Price':['mean','count'],'Kms':'max'})
# Out:
#                      Price           Kms
#                       mean count     max
# Kind
# Cabriolet     79272.636364    11   82000
# Coupé        543092.155556    90  150000
# Furgón       702054.698113    53  169000
# Hatchback    276554.828649  4056  159000
# Minivan      650000.000000     1  170000
# Monovolumen  270500.202837   705  156000
# Pick-Up      545194.551390  1547  218000
# Rural        330247.118644    59  149000
# SUV          380707.993103  1305  165000
# Sedán        338569.647032  2173  159000

# %% [markdown]
# ### Pivot table with Pandas

# %%
# Produces a long table
cars_produced_by_year_and_make = cars.groupby(['Year','Make'])[['Model']].count()
cars_produced_by_year_and_make.reset_index(inplace=True)
cars_produced_by_year_and_make.rename(columns={"Model":"Cars_Produced"},inplace=True)
cars_produced_by_year_and_make.head(10)
# Out:
#    Year           Make  Cars_Produced
# 0  2011       Chrysler             16
# 1  2011           Ford            665
# 2  2011          Honda            163
# 3  2011  Mercedes Benz             44
# 4  2011     Volkswagen           1124
# 5  2012       Chrysler              2
# 6  2012           Ford            609
# 7  2012          Honda            123
# 8  2012  Mercedes Benz             48
# 9  2012     Volkswagen           1052

# %%
# Makes it into a wide table
cars_produced_by_year_and_make_wide =  pd.pivot_table(cars_produced_by_year_and_make, values='Cars_Produced', index=['Year'],columns=['Make'])
cars_produced_by_year_and_make_wide
# Out:
# Make  Chrysler   Ford  Honda  Mercedes Benz  Volkswagen
# Year
# 2011      16.0  665.0  163.0           44.0      1124.0
# 2012       2.0  609.0  123.0           48.0      1052.0
# 2013       5.0  843.0   90.0           68.0      1083.0
# 2014       NaN  684.0   73.0           41.0       619.0
# 2015       NaN  593.0   18.0           14.0       609.0
# 2016       1.0  405.0   32.0           21.0       384.0
# 2017       NaN  184.0   20.0           15.0       254.0
# 2018       NaN   42.0    3.0            5.0        48.0

# %%
# To make it back into a long table
cars_produced_by_year_and_make_wide.reset_index().melt(id_vars="Year").head(10)
# Out:
#    Year      Make  value
# 0  2011  Chrysler   16.0
# 1  2012  Chrysler    2.0
# 2  2013  Chrysler    5.0
# 3  2014  Chrysler    NaN
# 4  2015  Chrysler    NaN
# 5  2016  Chrysler    1.0
# 6  2017  Chrysler    NaN
# 7  2018  Chrysler    NaN
# 8  2011      Ford  665.0
# 9  2012      Ford  609.0

# %% [markdown]
# ## Sorting

# %% [markdown]
# You can sort the output with the method `.sort_values()` that take at least 1 argument, the name of the column you want to sort the dataframe on, and an optional argument `ascending` that you need to set to `False` if you want the highest value at the top.

# %%
avg_price_and_kms_by_make = cars.groupby('Make')[['Price','Kms']].mean().sort_values("Price",ascending=False)

avg_price_and_kms_by_make
# Out:
#                        Price           Kms
# Make
# Mercedes Benz  512749.515625  67358.714844
# Honda          381520.603448  81619.659004
# Chrysler       366845.833333  79593.958333
# Ford           353041.877764  69897.515776
# Volkswagen     335441.534119  77660.223275

# %% [markdown]
# Pay attention to the fact that the column `'Make'` that we used in the `.groupby()` method is not a column in the output, it is now part of the index.
# For example we cannot get the column `'Make'` to create a boolean the same way as before, the following code returns an error:

# %%
avg_price_and_kms_by_make.columns
# Out:
# Index(['Price', 'Kms'], dtype='object')

# %% [markdown]
# The `KeyError` means that python cannot find what you are looking for in the place where you are looking for it: 'Make' is nowhere to be found among the columns of the dataframe cars_price_avg. It is being used as index for the rows now, but we can make sure that the columns in the index go back to being normal columns using the method `.reset_index()`

# %%
avg_price_and_kms_by_make.reset_index(inplace = True)
avg_price_and_kms_by_make.columns
# Out:
# Index(['Make', 'Price', 'Kms'], dtype='object')

# %%
avg_price_and_kms_by_make
# Out:
#             Make          Price           Kms
# 0  Mercedes Benz  512749.515625  67358.714844
# 1          Honda  381520.603448  81619.659004
# 2       Chrysler  366845.833333  79593.958333
# 3           Ford  353041.877764  69897.515776
# 4     Volkswagen  335441.534119  77660.223275

# %% [markdown]
# The special case of the method `.value_counts()`
#
# It groups the data by the column given to the method and counts how many entries there are for each value and sorts them by descending order

# %%
cars['Make'].value_counts()
# Out:
# Volkswagen       5173
# Ford             4025
# Honda             522
# Mercedes Benz     256
# Chrysler           24
# Name: Make, dtype: int64
